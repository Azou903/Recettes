# %%
from urllib.request import urlopen
import bs4
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd 
import numpy as np
import selenium
from selenium.webdriver.chrome.options import Options# for suppressing the browser
import time
from selenium.webdriver.common.by import By
import time
import pymongo
import urllib.request
from PIL import Image
from bson.objectid import ObjectId
from PIL import Image, ImageTk
from tkinter import *
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox
import pymongo
import pickle
import copy 
import re
import nltk
import json
import pipreqs

# %% [markdown]
# # Scraping le site petitchef pour extraire les recettes

# %%
def extract_type_plats_liens(driver)->list():
    """
    Cette fonction permet d'extraire trois liens qui menent vers les entrée, plats, et desserts 
    """
    driver.find_elements(By.CLASS_NAME,"sd-cmp-3V2Vm")[1].find_element(By.TAG_NAME,"button").click()
    #chrome_options.add_experimental_option("detach", True)
    return [i.text for i in driver.find_element(By.CLASS_NAME,"left").find_elements(By.TAG_NAME,"a")],[i.get_attribute('href') for i in driver.find_element(By.CLASS_NAME,"left").find_elements(By.TAG_NAME,"a")]

# %%
def extract_plus_de_recettes(driver,recipes_per_country)->list():
    """
    Cette fonction permet d'extraire plus de recettes de type 'plat' qui sont catégorisées par pays
    """
    time.sleep(4)
    driver.get(driver.find_element(By.LINK_TEXT,'Cuisine du monde').get_attribute('href')) #open the link cuisintes du mondes
    time.sleep(4)
    countries = [i.text for i in driver.find_elements(By.TAG_NAME,'h2')[0:13]]
    #print(countries)
    plus_de_recettes = [i.find_elements(By.TAG_NAME,'a')[-1].get_attribute('href') for i in driver.find_elements(By.CLASS_NAME,'ss-item') ]
    #print(plus_de_recettes)
    return list(zip(countries,plus_de_recettes))

# %%
def extract_recettes_links(driver,l:str)->list():
    """
    Permet d'extraire les liens qui menent vers les recettes 
    l: represente le lien d'une recette 
    """
    ### This function extracts all the links leading to recipes specific to each type of food (appéritif, plat, desser ...)
    driver.get(l)
    #recettes = [i.get_attribute('href') for i in driver.find_element(By.CLASS_NAME,"recipe-list").find_elements(By.TAG_NAME,"a")]
    recettes=list()
    #Loop over the pages of recipes and stops when the next button doesn't show up anymore
    while True: 
        try:         
            recettes.extend([i.get_attribute('href') for i in driver.find_element(By.CLASS_NAME,"recipe-list").find_elements(By.TAG_NAME,"a")])
            driver.find_element(By.CLASS_NAME, "next").click()
        except:
            return recettes

# %%
# extraire les liens des recettes
def extract_links_of_3_meals()->dict():
    """
    Permet de parcourir toutes les pages de chaque type de recette (entrée, plats, ou desserts) et extraire tous les liens
    """
    driver = webdriver.Chrome(executable_path='chromedriver.exe')
    driver.get('https://www.ptitchef.com/recettes/aperitif')
    type_and_link = extract_type_plats_liens(driver)
    recettes = dict() ## {'entry':[....], 'apperitif':[...],plats:{'Recettes de cuisine italienne':[],'Recettes de cuisine tunisienne':[....],....},'desserts':[....],....}
    recipes_per_country = dict() ## 
    recettes_type=type_and_link[0]
    liens=type_and_link[1]
    #recettes[liens[0].split("/")[-1]] = extract_recettes_links(driver)

    for l in range(1,4):
        if liens[l].split("/")[-1] != "plat":
            driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
            recettes[liens[l].split("/")[-1]] = extract_recettes_links(driver,liens[l])
        else:
            driver.get(liens[l])
            driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
            recipes_per_country = extract_plus_de_recettes(driver,recipes_per_country)
            recipes_per_country = {i[0]:i[1] for i in recipes_per_country}
            recipes_per_country = {keys:extract_recettes_links(driver,values) for keys, values in recipes_per_country.items()}
            recettes['plat'] = recipes_per_country
    return recettes

# %%
#delete irrelevant links:
"""
restructurer la dict des liens
"""
r2 = copy.copy(r)
r2['entree'] = [link for link in r['entree'] if 'ptitchef.com' in link]
r2['dessert'] = [link for link in r['dessert'] if 'ptitchef.com' in link]
r2['plat'] = {k:[link for link in v if 'ptitchef.com' in link] for k,v in r['plat'].items()}
#print(r2['plat'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30636\1136346824.py in <module>
#       2 import copy
#       3 import re
# ----> 4 r2 = copy.copy(r)
#       5 r2['entree'] = [link for link in r['entree'] if 'ptitchef.com' in link]
#       6 r2['dessert'] = [link for link in r['dessert'] if 'ptitchef.com' in link]
#
# NameError: name 'r' is not defined

# %%
"""
sauvegarder le dict des liens dans un pickle
"""
with open('Recipes_store.pkl', 'rb') as filehandler:
    loaded_object = pickle.load(filehandler)

# %% [markdown]
# # Extract Information from a recipe

# %%
def clean_one_ingred(string:str)->str:
    """
    nettoyer les ingrédients pour enlever certains mots tel que cl, ml, poignée et aussi les chiffre
    """
    pattern = r'\b\d+\b|\bcas\b|\bcl\b|\bcac\b|\bml\b|\bpoignée\b|\bgr\b'
    # Remove the specified patterns
    cleaned_string = re.sub(pattern, '', string)
    # Replace multiple spaces with a single space
    cleaned_string = re.sub(r'\s+', ' ', cleaned_string).strip()
    cleaned_string = cleaned_string.rstrip('.')
    return cleaned_string

# %%
# Clean the ingredients: REMOVE words like cl, cas, cac et les quantités cette fonction permettera aussi d'enregistrer la liste d'ingredients 
# will take a list of unclean ingredients. it will return a list of clean ingerdients without duplicates

def clean_ingredients(list_ingr_new:list)->list():
    """
    Permet d'utiliser la fonction précedente sur une liste de chaines de characteres
    """
    global list_ingredient_full
    #The pattern should be extended to include more words that can be removed
    pattern = r'\b\d+\b|\bcas\b|\bcl\b|\bcac\b|\bml\b|\bpoignée\b|\bc/.\b'
    list_ingr_new = [clean_one_ingred(i) for i in list_ingr_new]
    return list_ingredient_full+[i for i in list_ingr_new if i not in list_ingredient_full]

# %%
list_ingredient_full = list()

def extract_inf(link:str,country:str)->dict():
    """
    Extraire les informations d'une recette et les stocker dans un dictionnaire. tous les dictionnaires ont était sauvegardé dans 
    une base MongoDB
    """
    
    global recip_project
    global list_ingredient_full
    recettes_already_stored = [i['nom recette'] for i in recip_project.find()]
    #print(recettes_already_stored)
    driver.get(link)
    try:
        try:
            driver.find_elements(By.CLASS_NAME,"sd-cmp-3V2Vm")[1].find_element(By.TAG_NAME,"button").click()
            d_recettes['nom recette'] = nom


            d_recettes['pays'] = country

            inf = driver.find_elements(By.CLASS_NAME,'rdbsi-val')
            type_rec = inf[0].text
            d_recettes['Type de recette'] = type_rec

            nbr_personnes = inf[1].text
            d_recettes['nbr_personnes'] = nbr_personnes 

            duree_prep = inf[2].text
            d_recettes['duree_prep'] = duree_prep 


            duree_cuisson = inf[3].text
            d_recettes['durée_cuisson'] = duree_cuisson 


            diff = inf[4] .text
            d_recettes['difficulté'] = diff    


            ingredient_quant = [i.text for i in driver.find_element(By.CLASS_NAME,'ingredients-ul').find_elements(By.TAG_NAME,'label')]


            d_recettes['quantités et ingrédients'] = ingredient_quant 
            ingredient_clean = clean_ingredients(ingredient_quant)
            list_ingredient_full.extend(ingredient_clean)

            étapes_list = driver.find_element(By.CLASS_NAME,'rdisc-right').find_elements(By.TAG_NAME, 'li')
            étapes_dict = {str((i+1)):étapes_list[i].text for i in range(0,len(étapes_list))}

            img = [i.get_attribute('src') for i in driver.find_elements(By.TAG_NAME,'img')]

            d_recettes['image'] = img[7] 
            recip_project.insert_one(d_recettes)
            return d_recettes

        except:
            #print("test")
            d_recettes = {}
            nom = driver.find_element(By.TAG_NAME,'h1').text
            #print(nom)
            if nom not in recettes_already_stored:
                d_recettes['nom recette'] = nom


                d_recettes['pays'] = country

                inf = driver.find_elements(By.CLASS_NAME,'rdbsi-val')
                type_rec = inf[0].text
                d_recettes['Type de recette'] = type_rec

                nbr_personnes = inf[1].text
                d_recettes['nbr_personnes'] = nbr_personnes 

                duree_prep = inf[2].text
                d_recettes['duree_prep'] = duree_prep 


                duree_cuisson = inf[3].text
                d_recettes['durée_cuisson'] = duree_cuisson 


                diff = inf[4] .text
                d_recettes['difficulté'] = diff    


                ingredient_quant = [i.text for i in driver.find_element(By.CLASS_NAME,'ingredients-ul').find_elements(By.TAG_NAME,'label')]


                d_recettes['quantités et ingrédients'] = ingredient_quant 
                ingredient_clean = clean_ingredients(ingredient_quant)
                list_ingredient_full.extend(ingredient_clean)
                list_ingredient_full = list(set(list_ingredient_full))

                étapes_list = driver.find_element(By.CLASS_NAME,'rdisc-right').find_elements(By.TAG_NAME, 'li')
                étapes_dict = {str((i+1)):étapes_list[i].text for i in range(0,len(étapes_list))}

                d_recettes['étapes'] = étapes_dict


                img = [i.get_attribute('src') for i in driver.find_elements(By.TAG_NAME,'img')]

                d_recettes['image'] = img[7] 

                recip_project.insert_one(d_recettes)
                return d_recettes
            else:
                pass
    except:
        pass

# %% [markdown]
# # Extract information from all the recipes

# %%
"""
extraire le liens des recettes à partir du pickle
"""
with open('Recipes_store.pkl', 'rb') as filehandler:
    loaded_object = pickle.load(filehandler)
# Out:
# ['https://www.ptitchef.com/recettes/entree/tortilla-espagnole-pommes-de-terre-et-oignons-fid-1560941', 'https://www.ptitchef.com/recettes/entree/feuillete-de-camembert-fid-1564173', 'https://www.ptitchef.com/recettes/entree/beignets-de-crevettes-fid-1567505', 'https://www.ptitchef.com/recettes/entree/pain-a-l-ail-et-au-persil-fid-1561123', 'https://www.ptitchef.com/recettes/entree/guacamole-express-pas-a-pas-fid-1560710', 'https://www.ptitchef.com/dossiers/recettes/aperitifs-et-entrees-avec-du-foie-gras-aid-1012', 'https://www.ptitchef.com/recettes/entree/moelleux-de-courgettes-au-coeur-kiri-fid-1565724', 'https://www.ptitchef.com/recettes/entree/veloute-de-courgette-onctueux-fid-1566494', 'https://www.ptitchef.com/recettes/entree/salade-de-riz-fac
# %%
"""
Nous avons segmenter l'extraction des informations des recettes en trois parties. Nous avons commencé par extraire toutes les entrée ensuite tous les 
plats, ensuite tous les desserts. Le code ci-dessous représente l'extraction des desserts
"""
recettes_desserts = {}
option = webdriver.ChromeOptions()
driver = webdriver.Chrome(executable_path='chromedriver.exe',options=option)
links_plats = loaded_object['dessert']
recettes_desserts = [extract_inf(i,'None') for i in links_plats if i]
    
        
        
"""
list_ingredient_full étant definie comme une variable globale. Nous avons sauvegardé le contenu de cette variable dans un pickle 
Au tout début nous voulions aussi utiliser les ingrédients de cette liste comme input de l'interface mais nous avons abandonné l'idée 
au vu des besoins preprocessing requis afin d'éliminer tous les mots non pertinant (cuillere, rouge, rave, verte ...) à notre outil 
"""        
#Store the list of ingredients in a pickle 
object_to_pickle = list_ingredient_full
# Open the file in binary write mode 'wb'
with open('list_ingr.pkl', 'wb') as filehandler:
    pickle.dump(object_to_pickle, filehandler)
        
#recettes_plats = {k:[extract_inf(i) for i in v] for k,v in links_plats.items()}
# Out:
# C:\Users\ziedk\AppData\Local\Temp\ipykernel_29472\1691511373.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='chromedriver.exe',options=option)
# Gâteau au fromage blanc
# Comment faire du pain perdu ?
# Tarte au citron meringuée facile
# Gâteau au yaourt
# Gâteau au chocolat tout simple
# Voici l'une des premières recettes transmise par notre grand-mère
# Gâteau au lait concentré moelleux à souhait
# Gateau roulé au Nutella (ou confiture)
# Flan pâtissier comme chez le boulanger
# Charlotte aux fraises facile et rapide
# Bavarois framboise chocolat blanc (étapes et vidéo)
# Le dessert numéro 1 à faire avec une boîte de lait concentré!
# Fraisier (la recette pas à pas)
# Tiramisu italien
# Gâteau magique à la vanille pas à pas et vidéo
# Gâteau basque, la recette expliquée en détails
# Mousse au chocolat
# Roses des sables au chocolat
# Tarte aux pommes, la recette classique
# Tarte Tatin aux pommes
# Pâte à crêpes facile
# Gateau aux carottes
# Rochers à la noix de coco
# Madeleines au chocolat (pas à pas et en vidéo)
# Brownie au chocolat
# Fondant au chocolat et son coeur ultra coulant pas à pas
# Crème brûlée
# Tarte aux mirabelles
# Canelés bordelais
# Gâteau invisible aux pommes
# Tarte amandine aux poires, ou la célèbre Bourdaloue
# Le dessert numéro 1 à faire avec une boîte de lait concentré!
# Far breton aux pruneaux
# Flan à la noix de coco
# Gâteau aux pommes tout simple
# Riz au lait facile
# Tarte tropézienne expliquée pas à pas
# Le goûter d'hiver à faire avec seulement 2 ingrédients !
# Brioche dorée et moelleuse
# Flan aux œufs vanille
# Pasteis de Nata (petits flans portugais)
# Forêt noire, la recette expliquée en détails
# Crumble aux pommes et cannelle
# Tiramisu aux framboises simple et rapide
# Cookies aux pépites de chocolat
# Beignets moelleux pour Carnaval
# Tarte aux abricots
# Royal chocolat ou Trianon (vidéo et astuces)
# Tarte au citron facile
# Cannoli à la crème pâtissière vanille
# Tarte à la rhubarbe facile
# TARTE A LA DOUCE CREME DE CITRON
# FAR BRETON AUX POMMES
# Cake aux cerises
# Financiers noix de coco et pépites de chocolat
# Bouchées de chocolat aux Noix de Cajou et Caramel
# Délicieux gâteau aux pommes
# Gateau au yaourt à la noix de coco
# The clafoutis aux cerises
# MOELLEUX-FONDANT AU CHOCOLAT (végétalien)
# PATE A FRIRE et beignets aux pommes
# Bomboloni (beignets italiens)
# Gateau au yaourt et au Nutella selon Cyril Lignac
# Gâteau moelleux aux biscuits roses de Reims
# Crèmes speculoos
# Poissons d'Avril sablés
# Quatre-Quarts au citron
# Brownie Poulain
# Gâteau au fromage et aux mangues
# Muffins au coeur nutella
# Fondant Chocolat au lait & Rocher Praliné au coeur d'Ourson Guimauve
# Brownie au chocolat et aux noix d'Amazonie
# Figues rôties au miel
# Crème à l'orange
# Muffins banane, noix de coco et citron vert
# Tarte frangipane et caramel beurre salé
# Le gâteau Basque de ma grand-mère
# Clafoutis d'automne
# Donuts au four
# Bûche meringuée au chocolat et à la crème de clémentine
# Semoule au lait
# Gratin de framboises
# Gateau au fromage blanc & framboise (sans pâte)
# Moelleux au chocolat
# Verrine de mousse marscarpone au chocolat, éclats de spéculoos
# Gâteau fondant à l'ananas
# Gateau à la vanille
# MOUSSE AU CHOCOLAT BLANC AUX SPECULOOS SUR LIT DE POIRES CARAMEL
# Feuilletés tressés aux mirabelles
# Galette du roi Soleil : Amande & Chocolat
# Cake aux pêches
# L’Amandier à la Vanille
# Entremet aux fruits rouges
# Brioche tressée figue et framboise
# Cookies aux Cerises & Pralin Recette allégée sans beurre sans sucre
# Far Breton au Miel de Sarrasin et Poires Confites du Petit Bistro
# Charlotte façon Tiramisu
# Trifle framboise - sablé breton et pistache

# %%
"""
Compter le nombre de recette dans la base de données
"""

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["Recipes_db"]
recip_project = mydb["Recipes"]

count = 0

for x in recip_project.find():
    count += 1

print("Nombres de recettes extraites:",count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7752\2881177106.py in <module>
#       3 """
#       4
# ----> 5 myclient = pymongo.MongoClient("mongodb://localhost:27017/")
#       6 mydb = myclient["Recipes_db"]
#       7 recip_project = mydb["Recipes"]
#
# NameError: name 'pymongo' is not defined

# %% [markdown]
# # Extraire une liste d'ingrédients

# %%
"""
Extraire une liste d'ingrédients à partir du site qu'est ce que on mange
"""


option = webdriver.ChromeOptions()
driver = webdriver.Chrome(executable_path='chromedriver.exe',options=option)
driver.get('https://www.qu-est-ce-qu-on-mange.com/dans-mon-frigo')
links_to_scrap = [i for i in driver.find_element(By.ID,'les-ingredients_corps').find_elements(By.TAG_NAME,'DIV') if i.text
                  in ["Légumes","Viandes, poissons et oeufs","Féculents et légumineuses","Produits laitiers","Fruits et fruits secs","Autres","Charcuterie"]]



#print(links_to_scrap)
ingredients = list()

for i in range(0,len(links_to_scrap)):
    #print(ingredients)
    time.sleep(5)
    links_to_scrap = [i for i in driver.find_element(By.ID,'les-ingredients_corps').find_elements(By.TAG_NAME,'DIV') if i.text
                  in ["Légumes","Viandes, poissons et oeufs","Féculents et légumineuses","Produits laitiers","Fruits et fruits secs","Autres","Charcuterie"]]

    links_to_scrap[i].click()

    #time.sleep(5)
    if links_to_scrap[i].get_attribute("id") == "categorie-2":
        time.sleep(5)
        for j in range(0,len(driver.find_element(By.XPATH,"//div[@id='modale-contenu']").find_elements(By.TAG_NAME,'img'))):
            time.sleep(2)
            driver.find_element(By.XPATH,"//div[@id='modale-contenu']").find_elements(By.TAG_NAME,'img')[j].click()
            time.sleep(5)

            ingredients.extend([i.text for i in driver.find_element(By.XPATH,"//div[@id='modale-contenu']").find_elements(By.XPATH,"//div[@class='ingredient-de-liste']")])
            time.sleep(2)
            driver.get('https://www.qu-est-ce-qu-on-mange.com/dans-mon-frigo')
            time.sleep(3)
            #driver.back()
            driver.find_element(By.ID,'les-ingredients_corps').find_elements(By.TAG_NAME,'DIV')[1].click()
        
        driver.get('https://www.qu-est-ce-qu-on-mange.com/dans-mon-frigo')


            
    elif links_to_scrap[i].get_attribute("id") == "categorie-6":
        time.sleep(5)
        for j in range(0,len(driver.find_element(By.XPATH,"//div[@id='modale-contenu']").find_elements(By.TAG_NAME,'img'))):
            time.sleep(5)
            driver.find_element(By.XPATH,"//div[@id='modale-contenu']").find_elements(By.TAG_NAME,'img')[j].click()
            time.sleep(5)

            ingredients.extend([i.text for i in driver.find_element(By.XPATH,"//div[@id='modale-contenu']").find_elements(By.XPATH,"//div[@class='ingredient-de-liste']")])
            time.sleep(2)
            driver.get('https://www.qu-est-ce-qu-on-mange.com/dans-mon-frigo')
            time.sleep(3)
            #driver.back()
            driver.find_element(By.ID,'les-ingredients_corps').find_elements(By.TAG_NAME,'DIV')[6].click()
        
        driver.get('https://www.qu-est-ce-qu-on-mange.com/dans-mon-frigo')

        
    else: 
        #i.click()
        time.sleep(5)
        ingredients.extend([i.text for i in driver.find_element(By.XPATH,"//div[@id='modale-contenu']").find_elements(By.XPATH,"//div[@class='ingredient-de-liste']")])
        time.sleep(2)
        driver.find_element(By.CLASS_NAME,'modale-btn-close').click()

# %%
"""
Au vue de la maniere dont certains ingrédients sont écris nous avons du modifier un peu la liste d'ingrédients obtenues. En effet, 
sur le site 'é' a été codifiée par 'Ã©', 
"""

nouvelle_liste = list()

for element in ingr_list:
    nouvel_element = element.replace("Ã©", "é").replace("Ã¨", "è").replace("Ãª", "ê").replace("Ã¢","â").replace("Ã¯","ï").replace("Ã»","û").replace("Ã","à").replace("à´","ô")
    nouvelle_liste.append(nouvel_element)

    
"""
Stocker la nouvelle liste d'ingrédients dans un pickle
"""   
with open('Ingredients_clean.pkl', 'wb') as filehandler:
    pickle.dump(nouvelle_liste, filehandler)

# %% [markdown]
# # Tkinter Interface

# %%
"""
importer la liste d'ingrédients
"""
with open('Ingredients_clean.pkl', 'rb') as filehandler:
    ingr_list = pickle.load(filehandler)

#print(ingr_list)

# %%
def interface():

    """
    Creation de l'interface qui permet à l'utilisateur de choisir entre cusiner une entrée, un plat ou un dessert et d'entrer la liste des
    ingredients
    """

    def add_item():
        selected_item = my_list.get(tk.ACTIVE)
        if selected_item not in selected_ingr:
            selected_ingr.append(selected_item)
            update(selected_ingr)

    def remove_item():
        selected_item = my_list.get(tk.ACTIVE)
        if selected_item in selected_ingr:
            selected_ingr.remove(selected_item)
            update(selected_ingr)

    def validate():
        global selected_types

        selected_types = [type_labels[i] for i, selected in enumerate(type_vars) if selected.get()]

        if len(selected_types) == 0:
            messagebox.showinfo("Validation Error", "Please select at least one type (Entrée, Plat, or Dessert).")
        elif len(selected_ingr) == 0:
            messagebox.showinfo("Validation Error", "Please select at least one ingredient.")
        else:
            root.destroy()

    def check_selected_items():
        selected_items = "\n".join(selected_ingr)
        if selected_items:
            messagebox.showinfo("Selected Items", "Selected ingrs:\n" + selected_items)
        else:
            messagebox.showinfo("Selected Items", "No ingrs selected.")

    root = tk.Tk()
    root.title("ingrs Selector")

    main_frame = ttk.Frame(root, padding=20)
    main_frame.grid(column=0, row=0, sticky=(tk.W, tk.E, tk.N, tk.S))
    main_frame.columnconfigure(0, weight=1)
    main_frame.rowconfigure(1, weight=1)

    my_label = ttk.Label(main_frame, text="Choisir au moins un ingrédient et le type de plat souhaité", font=("Helvetica", 14), foreground="grey")
    my_label.grid(column=0, row=0, pady=(0, 20))

    my_entry = ttk.Entry(main_frame, font=("Helvetica", 20))
    my_entry.grid(column=0, row=1, sticky=(tk.W, tk.E))

    my_list = tk.Listbox(main_frame, width=50, selectmode=tk.SINGLE)  # Change selectmode to SINGLE
    my_list.grid(column=0, row=2, pady=20, sticky=(tk.W, tk.E, tk.N, tk.S))

    scrollbar = ttk.Scrollbar(main_frame, orient=tk.VERTICAL, command=my_list.yview)
    scrollbar.grid(column=1, row=2, sticky=(tk.N, tk.S))
    my_list.configure(yscrollcommand=scrollbar.set)

    add_button = ttk.Button(main_frame, text="Add", command=add_item)
    add_button.grid(column=0, row=3, pady=(0, 10), sticky=(tk.W, tk.E))

    remove_button = ttk.Button(main_frame, text="Remove", command=remove_item)
    remove_button.grid(column=0, row=4, pady=(0, 10), sticky=(tk.W, tk.E))

    validate_button = ttk.Button(main_frame, text="Validate", command=validate)
    validate_button.grid(column=0, row=5, pady=(0, 10), sticky=(tk.W, tk.E))

    check_selected_button = ttk.Button(main_frame, text="Check Selected Items", command=check_selected_items)
    check_selected_button.grid(column=0, row=6, pady=(0, 10), sticky=(tk.W, tk.E))

    ingrs = ingr_list

    selected_ingr = []

    def update(ingrs):
        my_list.delete(0, tk.END)
        for item in ingrs:
            my_list.insert(tk.END, item)

    update(ingrs)

    def check(e):
        typed = my_entry.get()

        if typed == '':
            data = ingrs
        else:
            data = []
            for item in ingrs:
                if typed.lower() in item.lower():
                    data.append(item)
        update(data)

    my_entry.bind("<KeyRelease>", check)

    type_labels = ["Entrée", "Plat", "Dessert"]
    type_vars = [tk.IntVar() for _ in type_labels]
    type_frame = ttk.Frame(main_frame)
    type_frame.grid(column=0, row=7, pady=10, sticky=(tk.W, tk.E))

    for i, type_label in enumerate(type_labels):
        ttk.Checkbutton(type_frame, text=type_label, variable=type_vars[i]).pack(side=tk.LEFT)

    root.mainloop()

    return selected_ingr, selected_types

# %% [markdown]
# # Matching the list of ingredients with recipes

# %%
def stemming_l_w(l:str)->list():
    """
    Uniformiser l'ingrédient afin d'assurer une meilleure comparaison entre les ingrédients de l'interface et ceux de la recette
    """
    
    new_list_ingr = list()
    stemmer=nltk.stem.SnowballStemmer('french')

    if type(l)==list:
        for i in l:
            new_list_ingr.extend([stemmer.stem(j) for j in i.split()])
        return new_list_ingr
    else:
        return [stemmer.stem(i) for i in l.split()]

# %%
"""
Importer la liste des recettes
"""

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["Recipes_db"]
recip_project = mydb["Recipes"]

count = 0

for x in recip_project.find():
    count += 1
    print("Nombre de recettes extraites",count)
# Out:
# {'_id': ObjectId('6506c6f4cf2ade5bd4bacf79'), 'nom recette': 'Muffins aux pépites de chocolat, la recette américaine', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Dessert', 'nbr_personnes': '12 parts', 'duree_prep': '20 min', 'durée_cuisson': '15 min', 'difficulté': 'facile', 'quantités et ingrédients': ['200 gr de farine', '150 gr de sucre', '100 gr de beurre', '2 oeufs', '120 ml de lait', '1 sachet de levure', '1 c. à café de bicarbonate de soude', '150 gr de pépites de chocolat'], 'étapes': {'1': 'Dans un bol, mélanger les ingrédients secs : la farine, le sucre, la levure et le bicarbonate de soude.\nDans un autre bol, mélanger les œufs et le lait. Puis ajouter ce mélange aux ingrédients secs et mélanger grossièrement.', '2': 'Ajouter le beurre fondu, mélanger rapidement, puis les pépites de chocolat.', '3': 'Dans un moule à muffins, mettre des caissettes à muffin, et remplir chaque caissette à ras-bord. Cuire 15 minutes à 180°C. Et voilà, vos muffins américains aux pépites de chocolat sont prêts !'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/muffins-aux-pepites-de-chocolat-la-recette-americaine--md-450709p702909.jpg'}
# {'_id': ObjectId('6506c6f8cf2ade5bd4bacf7a'), 'nom recette': 'Sundae, la douce glace américaine', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Dessert', 'nbr_personnes': '6 parts', 'duree_prep': '5 heures', 'durée_cuisson': 'facile', 'difficulté': '419 Kcal', 'quantités et ingrédients': ['40 cl de crème liquide entière', '250 gr de lait concentré sucré', '3 cas de caramel liquide', '1 poignée de cacahuètes grillées'], 'étapes': {'1': 'Battre la crème pour en faire une crème montée.', '2': 'Incorporez délicatement le lait concentré sucré à cette crème, et mettez au congélateur pendant 4 heures.', '3': 'Sortez la glace 5 minutes avant de servir. Servez des boules dans une coupe à glace, et versez du caramel dessus.', '4': 'Concassez les cacahuètes et parsemez en la glace.', '5': 'Et voilà, votre sundae est prêt !'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/sundae-la-douce-glace-americaine--md-453700p737203.jpg'}
# {'_id': ObjectId('6506c6fbcf2ade5bd4bacf7b'), 'nom recette': "Donuts à l'américaine", 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Dessert', 'nbr_personnes': '15 parts', 'duree_prep': '4 heures', 'durée_cuisson': '20 min', 'difficulté': 'moyen', 'quantités et ingrédients': ['350 gr de farine', '2 cac de levure de boulanger (ou 10 gr de levure fraîche)', '2 oeufs', '60 ml de lait', "60 ml d'eau", '2 c. à café de sel', '40 gr de sucre', '30 gr de beurre mou'], 'étapes': {'1': 'Hydrater la levure dans le lait tiède.', '2': "Dans le bol du pétrin, mettre la farine, le sucre, et le sel sur le côté, et former un puits. Y ajouter le mélange de lait et levure, l'eau, et les deux œufs.", '3': "Battre jusqu'à ce que le mélange soit bien homogène.", '4': "Continuer à battre et ajouter le beurre ramolli petit à petit. Continuer à battre jusqu'à ce que la pâte se décolle des parois. Laisser gonfler à température ambiante pendant 30 minutes.", '5': "Dégazer la pâte, c'est-à-dire appuyer dessus afin de faire sortir l'air présent dans la pâte. Mettre au frigo pendant 1 heure.", '6': "Dégazer la pâte à nouveau et l'étaler sur 1 cm d'épaisseur. La pâte doit rester souple, ne pas mettre trop de pression en l'étalant. Couper des cercles d'environ 7 cm de diamètre à l'aide d'un emporte pièce et les disposer sur une plaque.", '7': '
min', 'durée_cuisson': '20 min', 'difficulté': 'facile', 'quantités et ingrédients': ['140 g de farine', '½ cuillère à café de bicarbonate de soude', '115 g de beurre mou', '50 g de sucre en poudre', '50 g de sucre roux ou de vergeoise', '2 gros oeufs', '90 g de chocolat noir', '120 ml de lait fermenté'], 'étapes': {'1': 'Préparation des Cupcakes; préchauffez le four à 180° à thermostat 6. Dans un saladier, tamisez la farine et le bicarbonate puis réservez.', '2': "Faites fondre le chocolat et laissez tiédir. A l'aide d'un fouet électrique, mélangez le beurre mou avec les deux sucres jusqu'à ce que la préparation soit crémeuse.", '3': "Ajoutez les oeufs un à un. Baissez la vitesse du batteur et ajoutez le chocolat fondu ainsi que l'extrait de vanille.", '4': "Incorporez le tiers de la farine, quand elle est tout juste incorporée, ajoutez le tiers du lait et alternez ainsi jusqu'à épuisement des ingrédients.", '5': "Versez la pâte au 3/4 des caissettes en papier et faites cuire pendant 20 minutes environ. Vérifiez la cuisson en insérant un cure-dents au milieu d'un cupcake, il doit ressortir propre.", '6': "Quand les Cupcakes sont cuits, sortez-les du four et faites-les refroidir sur une grille. Attendez qu'ils aient complètement refroidi avant de les glacer.", '7': "Préparation du Glaçage ; dans une casserole de taille moyenne, délayer petit à petit la farine avec le lait. Faites chauffer à feu moyen, en remuant constamment, jusqu'à ce que le mélange bulle et devienne bien épais.", '8': 'Transférez le mélange dans un saladier et filmez-le au contact puis laissez-le refroidir à température ambiante pendant 30 minutes environ.', '9': "A l'aide d'un batteur électrique, fouettez le beurre pour le rendre crémeux. Ajoutez le sucre en poudre petit à petit et mélangez pendant 2 à 3 minutes.", '10': "Ajoutez l'extrait naturel de vanille, le mélange refroidi à base de farine et le colorant alimentaire rouge et mélangez, à vitesse moyenne, pendant encore 5 minutes.", '11': "Couvrez le glaçage et mettez-le au réfrigérateur pendant 15 minutes pour le faire raffermir un peu. Décorez les Cupcakes à l'aide d'une poche à douille."}, 'image': 'https://www.ptitchef.com/imgupl/recipe/cupcakes-au-chocolat-et-glacage-cremeux-a-la-vanille--md-372440p598916.jpg'}
# {'_id': ObjectId('6506c789cf2ade5bd4bacf85'), 'nom recette': 'Sandwich américain', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Autre', 'nbr_personnes': '3 parts', 'duree_prep': '10 heures', 'durée_cuisson': '5 min', 'difficulté': 'facile', 'quantités et ingrédients': ['1 baguette tradition (clic)', '3 tranches de jambon', 'beurre', 'sauce piment, ketchup, mayonnaise ou moutarde', 'gruyère râpé', 'frites'], 'étapes': {'1': 'Préchauffer le four à 230°.', '2': 'Couper la baguette en trois parts égales.', '3': 'Beurrer les sandwiches, mettre le jambon, la sauce, les frites et le gruyère.', '4': 'Mettre dans un plat allant au four et enfourner environ 5 minutes (le fromage doit être bien fondu).'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/sandwich-americain--md-67889p89682.jpg'}
# {'_id': ObjectId('6506c78ccf2ade5bd4bacf86'), 'nom recette': 'Les cupcakes plus américains tu meurs: Les Oreo Cupcakes', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Dessert', 'nbr_personnes': '4 parts', 'duree_prep': '15 min', 'durée_cuisson': '20 min', 'difficulté': 'facile', 'quantités et ingrédients': 
 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Goûter', 'nbr_personnes': '5 parts', 'duree_prep': '20 min', 'durée_cuisson': '12 min', 'difficulté': 'facile', 'quantités et ingrédients': ['2 1/2 cup de farine (313 g en arrondissant un peu!)', '3/4 teaspoon de sel (ou 1/4 de cuillère à café)', '1 1/2 stick de beurre doux à température ambiante (170 g)', '3/4 cup de sucre (120 g)', '1 gros oeuf', '1 teaspoon de vanille liquide (1 1/2 cuillère à café)'], 'étapes': {'1': "Battre le beurre et le sucre à l'aide d'un fouet électrique, à vitesse moyenne, jusqu'à ce que le mélange devienne clair et mousseux (environ 3 minutes si vous utilisez un robot, et 6 minutes environ si vous utilisez un batteur électrique à main).", '2': "Ajouter l’œuf et l'extrait de vanille et continuer de battre.\nBaisser la vitesse et ajouter le mélange farine/sel. Une fois que la farine est bien incorporée former une boule de pâte à la main.", '3': 'Diviser la pâte en deux. Former deux disques de 15 cm de diamètre environ. Emballer ces disques de film alimentaire et les mettre au frais 1 heure minimun.', '4': 'Positionner la plaque de cuisson au milieu du four et préchauffer à 180°C.', '5': "Abaisser un disque de pâte sur un plan de travail légèrement fariné (l'autre disque de pâte reste au frais en attendant). Personnellement je préfère réaliser des biscuits assez épais car ils sont plus facile à décorer, et ils noircissent moins que les petits à la cuisson. Donc si vous souhaitez réaliser des biscuits épais n'abaissez pas la pâte trop finement.\nSi la pâte a trop réchauffé et qu'elle colle au moment de l'étaler, placer à nouveau au frais pour 15 minutes environ.", '6': "Découper dans cette pâte autant de biscuits que vous pouvez avec des emportes-pièces et les placer sur une plaque couverte de papier sulfurisé.\nCuire les biscuits de 10 à 12 minutes environ, suivant l'épaisseur de la pâte. Les biscuits sont prêts quand les bords commencent à dorer.", '7': "Déposer les biscuits sur une grille jusqu'à complet refroidissement."}, 'image': 'https://www.ptitchef.com/imgupl/recipe/biscuits-americains-ou-sugar-cookies--md-143615p215050.jpg'}
# {'_id': ObjectId('6506c79ecf2ade5bd4bacf8d'), 'nom recette': "Queue de lotte à l'américaine", 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Plat', 'nbr_personnes': '2 parts', 'duree_prep': '10 min', 'durée_cuisson': '10 min', 'difficulté': 'facile', 'quantités et ingrédients': ['4 queues de lotte', '1 oignon', '2 échalotes', "1 gousse d'ail", '200 ml de coulis de tomate (ou concentré de tomate)', '1 verre de vin blanc sec (ou de  cognac)'], 'étapes': {'1': "Hachez l'oignon, l'échalote et l'ail et faites les blondir dans un peu d'huile d'olive.", '2': 'Ajoutez la lotte, un verre de cognac ou de vin blanc sec.', '3': 'Ajoutez 200 ml de coulis de tomate.', '4': 'Salez, poivrez et ajoutez deux petits piments de Cayenne.', '5': 'Laissez mijoter 15 minutes.', '6': 'Vous pouvez ajouter deux cuillères à soupe de crème fraîche épaisse.'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/queue-de-lotte-a-l-americaine--md-386460p616512.jpg'}
# {'_id': ObjectId('6506c7a0cf2ade5bd4bacf8e'), 'nom recette': "Le Mac'n cheese (célèbre gratin de pâte américain)", 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Plat', 'nbr_personnes': '4 parts', 'duree_prep': '10 min', 'durée_cuisson': '50 min', 'difficulté': 'facile', 'quantités et ingrédients': ['100 g de macaronis (pour moi ; coquillettes),', '250 ml de lait,', '2 càc de farine,', "1/2 càc d'ail semoule,", '255 g de cheddar râpé,', 'De la chapelure,', '10 à 20 g de beurre,', 'Du sel et du poivre.'], 'étapes': {'1': 'Préchauffer le four à 180°C soit th 6.\n\nDans une casserole d’eau bouillante salée, faire cuire les pâtes al dente.', '2': "Pendant ce temps, mélanger dans un saladier à l'aide d'un fouet, le lait, la farine, l’ail semoule et le sel.\n\nUne fois que les pâtes sont cuites, les verser dans un plat à gratin, ajouter le mélange au lait et le fromage râpé.\n\nBien mélanger.", '3': "Saupoudrer de chapelure et parsemer des morceaux de beurre dessus.\n\nCuire au four pendant 45 minutes (je pense que 25 à 30 min suffisent car c'était un peu sec)."}, 'image': 'https://www.ptitchef.com/imgupl/recipe/le-mac-n-cheese-celebre-gratin-de-pate-americain--md-47958p59098.jpg'}
# {'_id': ObjectId('6506c7a3cf2ade5bd4bacf8f'), 'nom recette': 'AILES de POULET façon KFC', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Plat', 'nbr_personnes': '4 parts', 'duree_prep': '10 min', 'durée_cuisson': '40 min', 'difficulté': 'facile', 'quantités et ingrédients': ["1 kg d'ailes de poulet", "3 gousses d'ail écrasées", "le jus d'un citron", "1 cuillère à soupe d'ajino moto ou sel chinois (facultatif mais ça donne le petit plus ...)", '1 cuillère à soupe de paprika', '1 oignon haché', '1 cuillère à café de sel', '1 cuillère à café de poivre'], 'étapes': {'1': 'La veille, ou le matin pour le soir:\nFaire mariner les ailes de poulet en les enrobant bien avec tous les ingrédients de la marinade. Laisser reposer plusieurs heures, voir toute la nuit.', '2': 'Le jour même, ou le soir :\nBien mélanger dans un sac congélation tous les ingrédients de la panure (c\'est ce qu\'on appelle la "farine assaisonnée") en secouant bien (sachet fermé ).', '3': 'Tremper chaque aile de poulet dans les œufs battus, puis dans la chapelure (pas fais ...), puis dans la farine assaisonnée. Bien, bien, bien enrober (!) et disposer chaque aile de poulet dans un plat préalablement huilé. Ne serrez pas trop les morceaux .', '4': "Faire cuire pendant 30/40 minutes à 200°C en couvrant d'aluminium. Les cinq dernières minutes enlever l'alu pour que ça dore un peu.", '5': 'Arrêter la cuisson. Enfin, au moment de servir, faire frire les ailes de poulet ( à la friteuse électrique) quelques minutes (3/4 minutes) et déposer sur du papier absorbant.', '6': 'Servir brûlant avec des frites et une salade ...'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/ailes-de-poulet-facon-kfc--md-442247p683892.jpg'}
# {'_id': ObjectId('6506c7a5cf2ade5bd4bacf90'), 'nom recette': 'Cookies américains chocolat - noix, sans farine', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Goûter', 'nbr_personnes': '4 parts', 'duree_prep': '12 min', 'durée_cuisson': '15 min', 'difficulté': 'facile', 'quantités et ingrédients': ['125 g de noix', '120 g de sucre cassonade', '40 g de cacao en poudre', '1 pincée de sel', '2 blancs d’oeufs'], 'étapes': {'1': 'Préchauffer votre four à 200 °C.', '2': 'Mettre les noix sur la plaque du four et les faire chauffer environ 5 minutes.', '3': 'Puis les concasser avec un rouleau à pâtisserie.', '4': 'Fouetter légèrement les blancs d’œuf à la main avec une pincée de sel.', '5': 'Puis ajouter le sucre, le cacao en poudre. Bien mélanger.', '6': 'Ajouter ensuite les noix et bien amalgamer.', '7': "Disposer de petits tas, que vous aplatissez un peu, sur la plaque de votre four recouverte d'une feuille de papier sulfurisé.", '8': 'Mettre au frais 30 minutes.', '9': 'Enfourner pour 15 minutes à 160 °C.'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/cookies-americains-chocolat-noix-sans-farine--md-437726p677578.jpg'}
# {'_id': ObjectId('6506c7a7cf2ade5bd4bacf91'), 'nom recette': 'Des Cupcakes typiquement américains, ou Cupcakes Oreo!!!!', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Dessert', 'nbr_personnes': '6 parts', 'duree_prep': '20 min', 'durée_cuisson': '20 min', 'difficulté': 'facile', 'quantités et ingrédients': ['100 g de beurre doux pommade (ou 50 g de beurre et 50 g de crème fraîche)', '65 g de sucre', '100 g de farine', '1 sachet de levure', '2 oeufs', '1/2 cuillère à café de vanille en poudre', '4 biscuits Oreo passés au mixer'], 'étapes': {'1': 'Préchauffer le four à 175°. Placer les caissettes en papier dans les moules à muffins.', '2': 'Dans une saladier, battre tous les ingrédients sauf les biscuits. Le mélange doit devenir pâle et lisse.', '3': "Rajouter ensuite les biscuits mixés que vous avez incorpore à la pâte, puis verser la pâte dans les moules, avant d'enfourner 20 minutes."}, 'image': 'https://www.ptitchef.com/imgupl/recipe/des-cupcakes-typiquement-americains-ou-cupcakes-oreo--md-167163p250042.jpg'}
# {'_id': ObjectId('6506c7aacf2ade5bd4bacf92'), 'nom recette': 'Encornets farcis aux amandes, sauce américaine', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Plat', 'nbr_personnes': '4 parts', 'duree_prep': '20 min', 'durée_cuisson': '2 min', 'difficulté': 'facile', 'quantités et ingrédients': ['8 encornets de 10 à 12 cm environ', '300 g de farce à tomate', "100 g d'amandes en poudre", '1 oeuf', '2 beaux oignons', "2 cuillères à soupe d'huile d'olive", 'Sel et poivre du moulin', '8 piques en bois', 'Pour la sauce américaine', '2 oignons', '1 boîte de tomates concassées', '1 boîte de concentré de tomate', '1 cuillère à soupe de cognac', '50 cl de vin blanc', "4 cuillères à soupe d'huile d'olive", "4 pincées de piment d'Espelette", 'Sel'], 'étapes': {'1': 'Préparer les encornets\nNettoyer et parer les encornets. Réserver les tentacules et les hacher.', '2': "Peler et émincer 2 oignons et les faire fondre dans de l'huile d'olive. Ajouter la farce, les tentacules, la poudre d'amandes et laisser cuire jusqu'au changement de couleur, saler et poivrer selon le goût.", '3': "Hors du feu, incorporer l'oeuf pour lier la farce. Bien remuer.", '4': "Retourner les encornets puis les remplir de farce à l'aide d'une cuillère à café et les fermer avec une pique en bois.", '5': "Préparer la sauce\nPeler et émincer les oignons puis les fondre. Dés qu'ils sont transparents ajouter les encornets et les faire revenir légèrement.", '6': "Incorporer les tomates concassées, le concentré de tomates, le vin blanc, le cognac, le piment d'espelette, saler légèrement.", '7': "Laisser mijoter, doucettement à feu doux, et à couvert, pendant au moins 1 heure 30. Rectifier l'assaisonnement 10 minutes avant de servir."}, 'image': 'https://www.ptitchef.com/imgupl/recipe/encornets-farcis-aux-amandes-sauce-americaine--md-164831p247026.jpg'}
# {'_id': ObjectId('6506c7adcf2ade5bd4bacf93'), 'nom recette': 'Queues de langouste à l’américaine.', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Plat', 'nbr_personnes':
'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/un-cake-parfume-au-guatemala-cake-au-mais-petits-oignons-et-piments-jalapenos--md-107917p159911.jpg'}
# ...
# {'_id': ObjectId('6506c843cf2ade5bd4bacfd6'), 'nom recette': 'Doughnuts ou donuts (Gâteaux Americains)', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Goûter', 'nbr_personnes': '15 parts', 'duree_prep': '15 min', 'durée_cuisson': '6 min', 'difficulté': 'facile', 'quantités et ingrédients': ['150 ml de lait', '55 g de sucre', 'une pincée de sel', '350 g de farine type 55', '11 g de levure sèche', '25 g de beurre à température ambiante'], 'étapes': {'1': "Mettre dans la map les ingrédients dans l'ordre.\nUtiliser le programme pétrissage uniquement.\nLaisser pointer une heure environ, appareil fermé.", '2': 'Former les beignets et les couvrir. Les laisser monter (environ 1/2 heure).', '3': 'Les cuire à la friteuse; les égoutter sur du papier absorbant.', '4': 'Une fois refroidis les glacer.'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/doughnuts-ou-donuts-gateaux-americains--md-337033p546829.jpg'}
# {'_id': ObjectId('6506c844cf2ade5bd4bacfd7'), 'nom recette': "Pain de maïs à l'américaine", 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Autre', 'nbr_personnes': '6 parts', 'duree_prep': '25 min', 'durée_cuisson': '20 min', 'difficulté': 'facile', 'quantités et ingrédients': ['2 1/2 tasses de semoule de maïs (60 ml)', '1 tasse de farine tout usage (250 ml)', '2 cuillères à table de poudre à pâte(30 ml)', '1/2 tasse de cassonade (125 ml)', '1 cuillère à thé de sel (5 ml)', '2 tasses de babeurre (475 ml)', '2 oeufs', '1/3 tasse de beurre fondu (75 ml)', '1 tasse de fromage cheddar râpé (250 ml)', '1 tasse de maïs (frais ou congelé et dégelé) (250 ml)', '1/2 livre de bacon frit croustillant, émietté', '3 piments jalapeno (facultatif)'], 'étapes': {'1': 'Chauffer une poêle en fonte sur le four à chaleur élevée.\nPréchauffer le four à 425°F.', '2': 'Fermer le rond du four sur lequel se trouve la poêle en fonte et ouvrir les autres ronds à température élevée.', '3': "Mélanger tous les ingrédients secs avec une fourchette. Ajoutez les ingrédients restants et bien mélangez. Enduire la poêle de fonte d'huile de maïs.", '4': "Versez la pâte lisse dans la poêle et passer sous le grill à 425°F pendant approximativement 20 minutes jusqu'à ce que le pain soit doré.", '5': 'Servir au déjeuner avec une omelette et du jambon à la mijoteuse.'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/pain-de-mais-a-l-americaine--md-319618p519966.jpg'}
# {'_id': ObjectId('6506c847cf2ade5bd4bacfd8'), 'nom recette': 'Tartine pour un brunch américain!', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Autre', 'nbr_personnes': '2 parts', 'duree_prep': '15 min', 'durée_cuisson': '35 min', 'difficulté': 'facile', 'quantités et ingrédients': ['2 tranches de pain de campagne', 'sauce au curry du commerce', "1 cuillère à soupe d'huile d'olive", 'sel, poivre, poudre de piment fort', '2 oeufs', '1 petite échalotte', '1 tomate', '1 demi poivron', '100 ml de lait', '4 tranches de pancetta', 'ciboulette pour décorer'], 'étapes': {'1': 'Préchauffez le four sur la position grill à 180°C.', '2': 'Faites griller les tranches de pain légèrement au grille-pain.', '3': "Mélangez l'oignon émincé, la tomate et le poivron coupés en cubes dans une poêle imbibée d'huile d'olive, ajoutez le sel, le poivre et le piment à votre convenance.\nLaissez mijoter 10 minutes.", '4': 'Faites griller les tranches de pancetta à la poêle.', '5': "Dans une casserole, mélangez, sur le feu, avec une cuillère en bois les 2 œufs et le lait, quand les œufs ont une bonne consistance d’œufs brouillés, ajoutez l'échalotte émincée.", '6': 'Tartinez les tranches de pain avec la sauce au curry, déposez la pancetta, ajoutez le mélange de légumes, puis les œufs brouillés.', '7': 'Enfournez entre 5 et 10 minutes au four position grill.\nDécorez avec la ciboulette avant de servir chaud.'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/tartine-pour-un-brunch-americain--md-302999p494815.jpg'}
# {'_id': ObjectId('6506c849cf2ade5bd4bacfd9'), 'nom recette': 'Ribs ou travers de porc américain au BBQ', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Plat', 'nbr_personnes': '5 parts', 'duree_prep': '30 min', 'durée_cuisson': '1 h 10 m', 'difficulté': 'facile', 'quantités et ingrédients': ['2 kg de croustilles ou cotillons de porc', '1 oignon piqué de clous de girofle', '2 cubes de maggi', '1/3 de tasse de miel liquide', "1/2 verre de jus d'orange", '1 tasse de sauce barbecue', '1/4 de tasse de vinaigre de cidre ou blanc', '1 cuillère à café de tabasco ou sauce chili', "2 gousses d'ail pilées", '1 cuillère à café de gingembre râpé', '3 cuillères à soupe de sauce soja', '4 cuillères à soupe de cassonade', 'sel et poivre'], 'étapes': {'1': "Placer la viande dans une grande cocotte et recouvrez-la d'eau.\nAjoutez les cubes maggi et l'oignon. Saler et poivrer.", '2': 'Amener le tout à ébullition et laisser cuire 40 minutes en écumant de temps à autre.', '3': 'Au bout de ce temps, retirer les travers de porc et égouttez-les dans une passoire.\nSécher avec une feuille de papier absorbant et laisser refroidir.', '4': "A l'aide d'un couteau bien aiguisé, enlever un peu de membrane gélatineuse qui se trouve sur la viande afin que la sauce s'y imprègne bien ensuite.\nCoupez la viande entre les côtes.", '5': 'Dans une saladier, ajouter tous les autres ingrédients, mélanger bien et ajouter la sauce sur la viande dans un grand plat et un peu profond.\nLaisser mariner pendant 6 heures minimum.', '6': 'Cuisson :\nAu BBQ, sous de bonnes braises contrôlées, faites cuire les ribs pendant 25 à 30 minutes tout en les badigeonnant de sauce de temps en temps et en les retournant souvent.', '7': "Dans l'assiette :\nServir les ribs avec des pommes de terre en robe des champs, des épis de maïs enrobés de papier aluminium, grillés au BBQ et dégustés avec une noix de beurre."}, 'image': 'https://www.ptitchef.com/imgupl/recipe/ribs-ou-travers-de-porc-americain-au-bbq--md-293309p479044.jpg'}
# {'_id': ObjectId('6506c84bcf2ade5bd4bacfda'), 'nom recette': "Gratin de boeuf à l'américaine", 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Plat', 'nbr_personnes': '6 parts', 'duree_prep': '20 min', 'durée_cuisson': '1 h 5 m', 'difficulté': 'facile', 'quantités et ingrédients': ['800 g de boeufs haché cru', '1 kg 600 de pommes de terre', '3 oignons', '2 carottes', '2 cuillères à soupe de sauce Worcestershire', '1 petite boite de conentré de tomate', '1 cube de bouillon de boeuf', '60 g de beurre', '15 cl de lait', 'sel et poivre'], 'étapes': {'1': "Faire saisir la viande hachée dans une noix de beurre en l'émiettant avec une cuillère en bois. Lorsqu'elle est dorée, ajouter les oignons et les carottes hachés. Remuer 5 minutes sur feu vif.", '2': 'Ajouter la sauce Worcestershire, le concentré de tomate et le cube de bouillon émietté.', '3': 'Laisser mijoter 30 minutes, en remuant de temps en temps.', '4': 'Faire cuire les pommes de terre, et réaliser un purée en y ajouter les 15 cl de lait et un peu de beurre. Saler, poivrer.', '5': "Verser la viande dans un plat à gratin, et étaler dessus la purée, (moi j'ai utilisé une poche à douille). Parsemer de petits cubes de beurre.", '6': 'Enfourner 30 minutes à 180°.', '7': 'A déguster bien chaud avec une salade verte.'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/gratin-de-boeuf-a-l-americaine--md-227011p360378.jpg'}
# {'_id': ObjectId('6506c84dcf2ade5bd4bacfdb'), 'nom recette': 'Le tour du monde en 232 recettes : Les îles samoa américaines', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Autre', 'nbr_personnes': '15 parts', 'duree_prep': '20 min', 'durée_cuisson': '25 min', 'difficulté': 'facile', 'quantités et ingrédients': ['1 kilo de farine', '500 g de sucre', '200 g de beurre', '2 oeufs', '25 g de maïzena', '2 pointe de couteau de vanille', '1 boîte de lait de coco'], 'étapes': {'1': "Mélanger le beurre et le sucre jusqu'à obtention d'un ensemble homogène.", '2': 'Ajouter les œufs, le lait de coco, la vanille.', '3': 'Mélanger encore et ajouter ensuite la farine et la maïzena.', '4': 'Ensuite, faire un boudin et couper des rondelles.', '5': 'Enfourner 25 minutes à 180°c.'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/le-tour-du-monde-en-232-recettes-les-iles-samoa-americaines--md-222929p352501.jpg'}
# {'_id': ObjectId('6506c84fcf2ade5bd4bacfdc'), 'nom recette': 'Cupcakes typiquement américains aux Oreo', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Autre', 'nbr_personnes': '6 parts', 'duree_prep': '20 min', 'durée_cuisson': '20 min', 'difficulté': 'facile', 'quantités et ingrédients': ['100 g de beurre doux pommade (ou 50 g de beurre et 50 g de crème fraîche)', '65 g de sucre', '100 g de farine', '1 sachet de levure', '2 oeufs', '1/2 cuillère à café de vanille en poudre', '4 Oreo passés au mixer'], 'étapes': {'1': 'Préchauffer le four à 175°.\nPlacer les caissettes en papier dans les moules à muffins.', '2': "Dans une saladier, battre tous les ingrédients sauf les biscuits (au batteur électrique, cela va plus vite). Le mélange doit devenir pâle et lisse. Rajouter ensuite les biscuits mixés et l'incorpore à la pâte, puis verser la pâte dans les moules, avant d'enfourner 20 minutes.", '3': 'Passé ce délai, sortir les cupcakes du four et les laisser refroidir avant de les enlever des moules à muffins.', '4': "Quand les cupcakes sont froids, préparer le glaçage :\nIncorpore à la maryse le sucre glace au beurre, puis étaler cette pâte sur les biscuits. Il ne reste plus qu'à saupoudrer les biscuits d'Oreo mixés, c'est prêt!!!"}, 'image': 'https://www.ptitchef.com/imgupl/recipe/cupcakes-typiquement-americains-aux-oreo--md-215018p336445.jpg'}
# {'_id': ObjectId('6506c851cf2ade5bd4bacfdd'), 'nom recette': "Cookies aux noix d'Amazonie et pépites de chocolat", 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Autre', 'nbr_personnes': '10 parts', 'duree_prep': '25 min', 'durée_cuisson': '14 min', 'difficulté': 'facile', 'quantités et ingrédients': ["noix d'Amazonie", '100 g de sucre roux'], 'étapes': {'1': "Noix d'Amazonie caramélisées - Pour un sachet :\nDans une poêle, à sec, faire torréfier les noix d'Amazonie: les faire chauffer doucement, jusqu'à ce qu'elles dégagent un doux parfum. Cela permet de les rendre croquantes et de leur donner le maximum de saveur.", '2': 'Dans une poêle antiadhésive, sur feu doux, faire fondre 100 g de sucre roux. Ne pas mélanger, juste laisser le sucre devenir liquide. Attention à ne pas laisser brûler le caramel !', '3': "Lorsque le sucre s'est liquéfié, verser les noix d'Amazonie, bien mélanger afin qu'elles soient bien recouvertes de caramel.\nAvant que les noix ait refroidi, les séparer en cassant le caramel du bout de la cuillère.", '4': "Pour les cookies - Pour une trentaine de gros biscuits :\nFaire fondre le beurre dans un bain-marie (dans un bol posé dans une casserole d'eau bouillante).\nMélanger la farine et le bicarbonate, préchauffer le four à 180°.", '5': "Dans un grand saladier, mélanger les sucres, la vanille, le beurre ramolli. Ajouter les œufs, un par un, en mélangeant bien à chaque fois.\nIncorporer peu à peu le mélange farine bicarbonate.\nAjouter les 3/4 des noix d'Amazonie coupées en petits morceaux et les pépites de chocolat.", '6': 'Sur une plaque recouvert de papier sulfurisé (ou sur un tapis en silicone posé sur une grille allant au four), disposer des petits tas de pâte formé avec une cuillère à soupe. Bien espacer les tas car la pâte coule en chauffant.\nDisposer quelques morceaux de noix sur chaque cookie.', '7': 'Enfourner et faire cuire de 8 à 11 minutes, selon que vous préférez vos cookies moelleux ou croustillants.\nA la fin de la cuisson, sortir la plaque du four et attendre quelques minutes que les biscuits durcissent avant de les retirer et de les stocker.'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/cookies-aux-noix-d-amazonie-et-pepites-de-chocolat--md-185151p279660.jpg'}
# {'_id': ObjectId('6506c853cf2ade5bd4bacfde'), 'nom recette': "A Thanksgiving's Recipe: soupe épicée au potiron", 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Plat', 'nbr_personnes': '2 parts', 'duree_prep': '10 min', 'durée_cuisson': '40 min', 'difficulté': 'facile', 'quantités et ingrédients': ['1 gros oignon en dés', '1 poireau', "1 gousse d'ail", '1 courgette en dés', '1 pomme de terre en dès', '500 g de potiron épluché, nettoyé et détaillé en dés', '1/2 cuillère à café de poivre blanc', '1/2 cuillère à café de curcuma', '1/2 c.à c de coriandre en poudre', '1 cuillère à café de curry', '1 cuillère à soupe de sucre roux', 'sel', 'beurre', 'crème fraîche', '1 grand verre de lait', 'coriandre fraîche'], 'étapes': {'1': "Faites chauffer 25 g de beurre avec un cuillère d'huile, faites y revenir les oignons, le poireau, l'ail et salez. Mélangez bien et laissez le tout s'attendrir.\nAprès quelques minutes de cuisson, ajoutez la pomme de terre, la courgette et le potiron.", '2': 'Mettez les épices ainsi que le sucre et mélangez bien de façon à ce que les épices imprègnent les autres ingrédients.', '3': "Après quelques instants, mouillez avec le lait et 1/2 litre d'eau.", '4': 'Portez à ébullition, couvrez votre cocotte et laissez cuire 30 à 35 minutes à feu doux.\nAprès ce temps, lorsque les légumes sont bien tendres, ajoutez la coriandre fraîche et mixez pour obtenir un velouté bien onctueux.', '5': 'Rajoutez alors 2 bonnes cuillères de crème fraîche (selon votre goût) et donnez encore quelques bouillons.', '6': 'Servez bien chaud!'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/a-thanksgiving-s-recipe-soupe-epicee-au-potiron--md-167302p250274.jpg'}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
def matching_count(db,selected_ingr:list())->dict():
    
    """
    compter pour chaque recette le nombre de matchs qui existent pour une liste d'ingrédients donnée
    """
    
    ### Matching evaluate the match of each recipe with my actual list of ingredients
    matching_dict = dict() # This dictionary will contain for each reciept the number of matches that occured with the list of ingredients that we have 
    #the comparison will be done by parsing through the list of ingredients and check if an ingredient appears in 
    #the list of ingeredients in the recipts. before comparing both the string ingredient and the strings in the list of ingredients in the recipet will be stemmed


    #myclient = pymongo.MongoClient("mongodb://localhost:27017/")
    #mydb = myclient["Recipes_db"]
    recip_project = db
    
    for r in recip_project:
        count_nbr_match = 0
        for i in selected_ingr:
            if stemming_l_w(i)[0] in stemming_l_w(r['quantités et ingrédients']):
                count_nbr_match+=1
        matching_dict[r["_id"]] = count_nbr_match
        
    return  matching_dict

# %%
def best_match_ids(matching_dict:dict())->list():
    """
    Trouve la position des recettes avec le plus haut matching score
    """
    max_count = max([v for v in matching_dict.values()])
    return [k for k,v in matching_dict.items() if v==max_count]

# %%
def matched_recipes(db,best_match_ids):
    """
    retourne la liste des recettes qui vont etre suggérées à l'utilisateur
    """
    final_recettes = list()

    recip_project = db
    
    return [r for r in recip_project if r['_id'] in best_match_ids]

# %%
def filter_recipes_database(recip_type:list())->list():
    
    """
    Permert de Filter la base de données MongoDb par plats, entrée ou desserts pour ne montrer
    """
    
    myclient = pymongo.MongoClient("mongodb://localhost:27017/")
    mydb = myclient["Recipes_db"]
    recip_project = mydb["Recipes"]
    result = list()
    for rt in recip_type:
        result.extend(recip_project.find({'Type de recette':rt}))
        
    
    return [r for r in result]

# %% [markdown]
# # Tkinter Final output

# %%
def display_recipes(recipes_data):
    """
    L'interface qui permet de visualiser les recettes retenues
    """
    
    def display_recipe_details(selected_recipe):
        title_label.config(text=selected_recipe['nom recette'])
        type_label.config(text=f"Type de recette: {selected_recipe['Type de recette']}")
        servings_label.config(text=f"Nombre de personnes: {selected_recipe['nbr_personnes']}")

        # Calculate the total preparation time and cooking time
        total_prep_time = selected_recipe['duree_prep']
        total_cooking_time = selected_recipe['durée_cuisson']

        preparation_time_label.config(text=f"Temps de préparation: {total_prep_time}")
        cooking_time_label.config(text=f"Durée de cuisson: {total_cooking_time}")
        difficulty_label.config(text=f"Difficulté: {selected_recipe['difficulté']}")

        ingredients_text.config(state=tk.NORMAL)
        ingredients_text.delete('1.0', tk.END)
        for ingredient in selected_recipe['quantités et ingrédients']:
            ingredients_text.insert(tk.END, f"{ingredient}\n")
        ingredients_text.config(state=tk.DISABLED)
        steps_text.config(state=tk.NORMAL)
        steps_text.delete('1.0', tk.END)
        for step_number, step_text in selected_recipe['étapes'].items():
            steps_text.insert(tk.END, f"Étape {step_number}:\n{step_text}\n\n")
        steps_text.config(state=tk.DISABLED)
        image_url = selected_recipe['image']
        image = Image.open(requests.get(image_url, stream=True).raw)
        image = image.resize((300, 300), Image.ANTIALIAS)
        photo = ImageTk.PhotoImage(image)
        image_label.config(image=photo)
        image_label.photo = photo

    root = tk.Tk()
    root.title("Recipe")

    listbox_frame = ttk.Frame(root)
    listbox_frame.pack(side=tk.LEFT, fill=tk.Y)

    recipes_listbox = tk.Listbox(listbox_frame, font=("Arial", 12), selectmode=tk.SINGLE)
    recipes_listbox.pack(fill=tk.BOTH, expand=True)

    for recipe in recipes_data:
        recipes_listbox.insert(tk.END, recipe['nom recette'])

    details_frame = ttk.Frame(root)
    details_frame.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)

    title_label = ttk.Label(details_frame, text="", font=("Arial", 20))
    title_label.pack()

    type_label = ttk.Label(details_frame, text="", font=("Arial", 12))
    type_label.pack()

    servings_label = ttk.Label(details_frame, text="", font=("Arial", 12))
    servings_label.pack()

    preparation_time_label = ttk.Label(details_frame, text="", font=("Arial", 12))
    preparation_time_label.pack()
    cooking_time_label = ttk.Label(details_frame, text="", font=("Arial", 12))
    cooking_time_label.pack()
    difficulty_label = ttk.Label(details_frame, text="", font=("Arial", 12))
    difficulty_label.pack()

    ingredients_text = tk.Text(details_frame, height=10, width=45, font=("Arial", 12))
    ingredients_text.pack(fill=tk.BOTH, expand=True)
    ingredients_text.config(state=tk.DISABLED)

    steps_text = tk.Text(details_frame, height=15, width=45, font=("Arial", 12))
    steps_text.pack(fill=tk.BOTH, expand=True)
    steps_text.config(state=tk.DISABLED)

    image_label = ttk.Label(details_frame)
    image_label.pack()

    def on_select(event):
        selected_index = recipes_listbox.curselection()
        if selected_index:
            selected_index = int(selected_index[0])
            selected_recipe = recipes_data[selected_index]
            display_recipe_details(selected_recipe)

    recipes_listbox.bind('<<ListboxSelect>>', on_select)

    root.mainloop()

# %% [markdown]
# # Code à executer pour lancer le projet

# %%
"""
Avant d'executer ce code certaines fonctions doivent etre executer. Veuillez executer tout le code à partir du Titre "Tkinter Interface"
"""


myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["Recipes_db"]
recip_project = mydb["Recipes"]

selected_ingr,recipe_type=interface()
#print(selected_ingr)
filtered_db = filter_recipes_database(recipe_type)

#print(filtered_db)
count_matches = matching_count(filtered_db,selected_ingr) # This resutrns a dictionary that counts the occurence of each ingredients in each recipe 
match_ids = best_match_ids(count_matches) #Returns the mongodb ids of the recipes with the highest match. Those that contain most or all of the ingredients selected 
recipes_final = matched_recipes(filtered_db,match_ids)
display_recipes(recipes_final)
# Out:
# ['Brocoli']
# [{'_id': ObjectId('6506c6f4cf2ade5bd4bacf79'), 'nom recette': 'Muffins aux pépites de chocolat, la recette américaine', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Dessert', 'nbr_personnes': '12 parts', 'duree_prep': '20 min', 'durée_cuisson': '15 min', 'difficulté': 'facile', 'quantités et ingrédients': ['200 gr de farine', '150 gr de sucre', '100 gr de beurre', '2 oeufs', '120 ml de lait', '1 sachet de levure', '1 c. à café de bicarbonate de soude', '150 gr de pépites de chocolat'], 'étapes': {'1': 'Dans un bol, mélanger les ingrédients secs : la farine, le sucre, la levure et le bicarbonate de soude.\nDans un autre bol, mélanger les œufs et le lait. Puis ajouter ce mélange aux ingrédients secs et mélanger grossièrement.', '2': 'Ajouter le beurre fondu, mélanger rapidement, puis les pépites de chocolat.', '3': 'Dans un moule à muffins, mettre des caissettes à muffin, et remplir chaque caissette à ras-bord. Cuire 15 minutes à 180°C. Et voilà, vos muffins américains aux pépites de chocolat sont prêts !'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/muffins-aux-pepites-de-chocolat-la-recette-americaine--md-450709p702909.jpg'}, {'_id': ObjectId('6506c6f8cf2ade5bd4bacf7a'), 'nom recette': 'Sundae, la douce glace américaine', 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Dessert', 'nbr_personnes': '6 parts', 'duree_prep': '5 heures', 'durée_cuisson': 'facile', 'difficulté': '419 Kcal', 'quantités et ingrédients': ['40 cl de crème liquide entière', '250 gr de lait concentré sucré', '3 cas de caramel liquide', '1 poignée de cacahuètes grillées'], 'étapes': {'1': 'Battre la crème pour en faire une crème montée.', '2': 'Incorporez délicatement le lait concentré sucré à cette crème, et mettez au congélateur pendant 4 heures.', '3': 'Sortez la glace 5 minutes avant de servir. Servez des boules dans une coupe à glace, et versez du caramel dessus.', '4': 'Concassez les cacahuètes et parsemez en la glace.', '5': 'Et voilà, votre sundae est prêt !'}, 'image': 'https://www.ptitchef.com/imgupl/recipe/sundae-la-douce-glace-americaine--md-453700p737203.jpg'}, {'_id': ObjectId('6506c6fbcf2ade5bd4bacf7b'), 'nom recette': "Donuts à l'américaine", 'pays': 'Recettes de cuisine américaine', 'Type de recette': 'Dessert', 'nbr_personnes': '15 parts', 'duree_prep': '4 heures', 'durée_cuisson': '20 min', 'difficulté': 'moyen', 'quantités et ingrédients': ['350 gr de farine', '2 cac de levure de boulanger (ou 10 gr de levure fraîche)', '2 oeufs', '60 ml de lait', "60 ml d'eau", '2 c. à café de sel', '40 gr de sucre', '30 gr de beurre mou'], 'étapes': {'1': 'Hydrater la levure dans le lait tiède.', '2': "Dans le bol du pétrin, mettre la farine, le sucre, et le sel sur le côté, et former un puits. Y ajouter le mélange de lait et levure, l'eau, et les deux œufs.", '3': "Battre jusqu'à ce que le mélange soit bien homogène.", '4': "Continuer à battre et ajouter le beurre ramolli petit à petit. Continuer à battre jusqu'à ce que la pâte se décolle des parois. Laisser gonfler à température ambiante pendant 30 minutes.", '5': "Dégazer la pâte, c'est-à-dire appuyer dessus afin de faire sortir l'air présent dans la pâte. Mettre au frigo pendant 1 heure.", '6': "Dégazer la pâte à nouveau et l'étaler sur 1 cm d'épaisseur. La pâte doit rester souple, ne pas mettre trop de pression en l'étalant. Couper des cercles d'environ 7 cm de diamètre à l'aide d'un emporte pièce et les disposer sur une plaque.", '7': 'Avec un plus petit emporte-pièce, faire des trous dans chaque cercle. Puis, laisser reposer 1 heure à température ambiante.', '8': 'Cuire à la friteuse, réglée si possible à 170°C. Laisser 2 minutes par face, puis déposer sur du papier absorbant.', '9': "Le glaçage :\nMélanger le sucre glace et le lait jusqu'à obtenir une préparation uniforme.", '10': "Tremper les donuts dans le glaçage (vous pouvez le colorer) et l'étaler uniformément à l'aide d'une cuillère.", '11': 'Saupoudrer de décorations en sucre. Et voilà, vos donuts son ...
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\ziedk\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\ziedk\AppData\Local\Temp\ipykernel_16312\346163768.py", line 83, in on_select
#     display_recipe_details(selected_recipe)
#   File "C:\Users\ziedk\AppData\Local\Temp\ipykernel_16312\346163768.py", line 30, in display_recipe_details
#     image = Image.open(requests.get(image_url, stream=True).raw)
# AttributeError: type object 'Image' has no attribute 'open'
